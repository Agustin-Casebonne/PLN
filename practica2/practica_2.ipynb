# %%
import pandas as pd
import torch
from docx import Document
import os
import nltk

# %%
doc1= Document(r"practice_bow_similarity\doc01.docx")
doc2= Document(r"practice_bow_similarity\doc02.docx")
doc3= Document(r"practice_bow_similarity\doc03.docx")
doc4= Document(r"practice_bow_similarity\doc04.docx")   
doc5= Document(r"practice_bow_similarity\doc05.docx")
doc6= Document(r"practice_bow_similarity\doc06.docx")
doc7= Document(r"practice_bow_similarity\doc07.docx")
doc8= Document(r"practice_bow_similarity\doc08.docx")
doc9= Document(r"practice_bow_similarity\doc09.docx")
doc10= Document(r"practice_bow_similarity\doc10.docx")
doc11= Document(r"practice_bow_similarity\doc11.docx")
doc12= Document(r"practice_bow_similarity\doc12.docx")

# %%
def leer_docx(doc):
    doc = "\n".join(p.text for p in doc.paragraphs)
    return doc

doc1_text = leer_docx(doc1)
for i in range(1, 13):
    doc = globals()[f'doc{i}']
    doc_text = leer_docx(doc).lower()
    globals()[f'doc{i}_text'] = doc_text

# %%
print(doc3_text)
# Out:
# las aplicaciones móviles más descargadas del mes
#
# el auge de las aplicaciones móviles continúa creciendo a pasos agigantados. este mes, la aplicación de edición de video clipmaster ha liderado las listas de descargas, seguida de cerca por la app de fitness fitjourney. ambas aplicaciones demuestran el interés creciente de los usuarios por herramientas que les permitan mejorar su calidad de vida y expresarse creativamente. con millones de apps disponibles, es evidente que los móviles se han convertido en herramientas esenciales para la vida cotidiana.

# %%
nltk.download("stopwords")
from nltk.corpus import stopwords

stop_words = set(stopwords.words("spanish"))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\agust\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(doc1_text)
puntuacion = [".", ",", ";", ":", "!", "?", "(", ")", "[", "]", "{", "}", "'", '"', "-", "_", "/", "\\", "@", "#", "$", "%", "^", "&", "*", "+", "=", "<", ">", "|"]
doc1_text = stop_words = [word for word in doc1_text.split() if word not in stop_words and word not in puntuacion]
print(doc1_text)
# Out:
# nuevo smartphone de alta gama promete revolucionar el mercado
#
# hoy se anunció el lanzamiento del último smartphone de la reconocida marca tecnophone. este nuevo dispositivo, denominado tecnophone xz, promete características sobresalientes que seguramente causarán revuelo en la industria móvil. incorpora una pantalla oled de 6.7 pulgadas, un procesador de última generación y una memoria ram de 12 gb. además, para los amantes de la fotografía, el tecnophone xz posee una cámara triple con una resolución de 108 megapíxeles. los expertos ya lo han calificado como el "móvil del año" y esperan ver su impacto en el mercado en los próximos meses.
#
# ...
